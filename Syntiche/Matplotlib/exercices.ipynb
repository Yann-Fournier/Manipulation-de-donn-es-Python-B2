# %% [markdown]
# ### Création des données factices :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Création d'un DataFrame factice avec des données aléatoires
np.random.seed(42)
date = pd.date_range(start='2022-01-01', end='2022-04-15')
data = {
    'Date': date,
    'Ventes': np.random.randint(100, 1000, size=len(date)),
    'Produit': np.random.choice(['A', 'B', 'C'], size=len(date))
}
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#         Date  Ventes Produit
# 0 2022-01-01     202       A
# 1 2022-01-02     535       A
# 2 2022-01-03     960       B
# 3 2022-01-04     370       C
# 4 2022-01-05     206       A

# %% [markdown]
# 1. **Tracé d'une série temporelle des ventes** :
#    Tracez un graphe montrant l'évolution des ventes au fil du temps.

# %%
plt.plot(df['Date'],df['Ventes'])

# %% [markdown]
# 2. **Histogramme des ventes par produit** :
#    Tracez un histogramme montrant la répartition des ventes par produit.

# %%
plt.hist(df['Produit'])
# Out:
# (array([41.,  0.,  0.,  0.,  0., 23.,  0.,  0.,  0., 41.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 3. **Diagramme circulaire des ventes par produit** :
#    Tracez un diagramme circulaire montrant la part de chaque produit dans les ventes totales.

# %%
df2 = df.groupby('Produit')['Ventes'].sum()
labels = ['A', 'B', 'C']
print(df2)
plt.pie(df2, labels=labels,  autopct='%1.1f%%', colors=['skyblue', 'lightgreen', 'lightcoral'])
# Out:
# Produit
# A    21786
# B    11640
# C    23508
# Name: Ventes, dtype: int32
# ([<matplotlib.patches.Wedge at 0x21cdfa25450>,
#   <matplotlib.patches.Wedge at 0x21cdfcc4790>,
#   <matplotlib.patches.Wedge at 0x21cdfcc5f10>],
#  [Text(0.396396834180551, 1.0260943182045386, 'A'),
#   Text(-1.0950379762520444, 0.10436393326157895, 'B'),
#   Text(0.2972566305562459, -1.059074357913715, 'C')],
#  [Text(0.21621645500757325, 0.5596878099297483, '38.3%'),
#   Text(-0.5972934415920241, 0.05692578177904305, '20.4%'),
#   Text(0.16213998030340684, -0.57767692249839, '41.3%')])

# %% [markdown]
# 4. **Diagramme en barres des ventes par jour** :
#    Tracez un diagramme en barres montrant les ventes pour chaque jour.

# %%
plt.bar(df['Date'], df['Ventes'])
# Out:
# <BarContainer object of 105 artists>

# %% [markdown]
# 5. **Diagramme en secteurs des ventes par mois** :
#    Tracez un diagramme en secteurs montrant la répartition des ventes par mois.

# %%
df['Mois'] = df['Date'].dt.month
dfMois = df.groupby('Mois')['Ventes'].sum()
plt.pie(dfMois, labels=['Janvier', 'Fevrier', 'Mars', 'Avril'], autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightgreen', 'lightcoral', 'lightsalmon'])
# Out:
# ([<matplotlib.patches.Wedge at 0x21cdfe035d0>,
#   <matplotlib.patches.Wedge at 0x21cdfe37410>,
#   <matplotlib.patches.Wedge at 0x21cdfe48c50>,
#   <matplotlib.patches.Wedge at 0x21cdfe484d0>],
#  [Text(-0.8055190623517713, 0.7490921439902594, 'Janvier'),
#   Text(-0.5803043249763933, -0.934476800361407, 'Fevrier'),
#   Text(1.0487458539851116, -0.33186161837283773, 'Mars'),
#   Text(0.5272441101007592, 0.9654085396162905, 'Avril')],
#  [Text(-0.43937403401005704, 0.4085957149037778, '26.2%'),
#   Text(-0.31652963180530536, -0.5097146183789492, '30.0%'),
#   Text(0.5720431930827881, -0.181015428203366, '27.9%'),
#   Text(0.28758769641859594, 0.5265864761543402, '15.9%')])

# %% [markdown]
# 6. **Boîte à moustaches des ventes par produit** :
#    Tracez un diagramme en boîte montrant la distribution des ventes pour chaque produit.

# %%
A = df[df['Produit'] == 'A']
B = df[df['Produit'] == 'B']
C = df[df['Produit'] == 'C']
plt.boxplot([A['Ventes'], B['Ventes'], C['Ventes']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21cdfe8bf10>,
#   <matplotlib.lines.Line2D at 0x21cdfea0950>,
#   <matplotlib.lines.Line2D at 0x21cdfea3ad0>,
#   <matplotlib.lines.Line2D at 0x21cdfea82d0>,
#   <matplotlib.lines.Line2D at 0x21cdfeab550>,
#   <matplotlib.lines.Line2D at 0x21cdfeabd90>],
#  'caps': [<matplotlib.lines.Line2D at 0x21cdfea1190>,
#   <matplotlib.lines.Line2D at 0x21cdfea1a10>,
#   <matplotlib.lines.Line2D at 0x21cdfea8ad0>,
#   <matplotlib.lines.Line2D at 0x21cdfea9410>,
#   <matplotlib.lines.Line2D at 0x21cdfeb8690>,
#   <matplotlib.lines.Line2D at 0x21cdfeb8ed0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x21cdfde3390>,
#   <matplotlib.lines.Line2D at 0x21cdfea3250>,
#   <matplotlib.lines.Line2D at 0x21cdfeaad10>],
#  'medians': [<matplotlib.lines.Line2D at 0x21cdfea2350>,
#   <matplotlib.lines.Line2D at 0x21cdfea9c90>,
#   <matplotlib.lines.Line2D at 0x21cdfeb9690>],
#  'fliers': [<matplotlib.lines.Line2D at 0x21cdfea0910>,
#   <matplotlib.lines.Line2D at 0x21cdfe548d0>,
#   <matplotlib.lines.Line2D at 0x21cdfeb9f90>],
#  'means': []}

# %% [markdown]
# 7. **Violin plot des ventes par produit** :
#    Tracez un diagramme en violon montrant la distribution des ventes pour chaque produit.

# %%
plt.violinplot(df2)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x21cdfefccd0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x21cdfd39610>,
#  'cmins': <matplotlib.collections.LineCollection at 0x21cdfde9690>,
#  'cbars': <matplotlib.collections.LineCollection at 0x21cdfc5fa10>}

# %% [markdown]
# 8. **Heatmap des ventes par jour de la semaine et produit** :
#    Tracez une heatmap montrant les ventes moyennes par jour de la semaine et produit.

# %% [markdown]
# 9. **Tracé de répartition des ventes par produit** :
#    Tracez un tracé de répartition montrant la distribution des ventes par produit.

# %% [markdown]
# 10. **Diagramme en barres des ventes mensuelles cumulatives** :
#     Tracez un diagramme en barres montrant les ventes mensuelles cumulatives.

# %% [markdown]
# 11. **Tracé de répartition des ventes par produit avec seaborn** :
#     Tracez un tracé de répartition montrant la distribution des ventes par produit.

# %% [markdown]
# 12. **Graphique à barres empilées des ventes par produit et par mois** :
#     Tracez un graphique à barres empilées montrant les ventes par produit pour chaque mois.

# %% [markdown]
# 13. **Nuage de points avec régression linéaire des ventes par date** :
#     Tracez un nuage de points avec une ligne de régression linéaire montrant la relation entre les ventes et la date.

# %% [markdown]
# 14. **Tracé de répartition des ventes par produit avec des barres d'erreur** :
#     Tracez un tracé de répartition avec des barres d'erreur montrant la distribution des ventes par produit.
