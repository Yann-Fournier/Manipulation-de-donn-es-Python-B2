# %% [markdown]
# # **INITIATION AU MACHINE LEARNING PARTIE 2 : prédiction des survivants au naufrage du titanic**

# %% [markdown]
# Dans la première partie, vous avez suivi le protocole expérimental sur la prédiciton du prix en bourse de l'action de apple à la fermeture.

# %% [markdown]
# Ici, on change de dimension, on travaille sur les données du titanic .

# %% [markdown]
# La différence entre le Lab 1 et le Lab 2 est que , dans le lab 2, on attend de vous à ce que vous puissiez montrez comment vous vous y prendrez pour résoudre un problème de classification, ainsi si un individu a survécu, il appartiendra à la lcasse une, sinon il appartiendra à la classe 2 !!!!

# %% [markdown]
# PAS DE PANIQUE, vosu aurez des étapes à suivre, les mêmes étapes mais sans plus .

# %% [markdown]
# # LAB 1 : LA REGRESSION LOGISTIQUE

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Ynov/Bachelor\ 2/python/
# Out:
# /content/drive/MyDrive/Ynov/Bachelor 2/python

# %%
import numpy as np
import pandas as pd

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# (Ce text est repris de kaggle)
#
# Il s'agit de la légendaire compétition Titanic ML (https://www.kaggle.com/c/titanic)
#
# - le meilleur et premier défi pour vous plonger dans les compétitions de ML.
#
# Le concours est simple : utilisez l'apprentissage automatique pour créer un modèle qui prédit quels passagers ont survécu au naufrage du Titanic.
#
# Bien qu'il y ait eu une part de chance dans la survie, il semble que certains groupes de personnes aient plus de chances de survivre que d'autres.
#
# Dans ce défi, nous vous demandons de créer un modèle prédictif de type-classification.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import graphviz
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.model_selection import GridSearchCV
import seaborn as sn

# %% [markdown]
# Récupérez les données

# %%
df = pd.read_csv("Titanic.csv")

# %%
df

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # STEP 1 : DATA PREPROCESSING

# %% [markdown]
# Avant tout , retenez que les étapes suivantes ne sont que des propostions, libre ç vosu de faire comme bon vosu semble.

# %% [markdown]
# **1) observez vos données, existe-t-il des données manquantes ? Si oui gérez les (à ce stade très primaire de votre apprentissage, je vous conseil de les supprimer)** --> c'est le cas des colonnes ticket et du nom

# %% [markdown]
# **2) On a dit que les modèles de machine learning ne comprennent pas les textes (alphanumérique), en revanche les chiffres oui.
# Cherchez comment encoder (cad transformer) la colonne Embarked et Sex**

# %% [markdown]
# afin d'obtenir soit :
#
# 2.1 )  sur la même colonne :
#
# - Pour les lieux d'embraquements
#
# C = 0 , S = 1 et Q = 2
#
# - Pour le Sexe :
#
# H = 0 et F = 1
#
#
# Le problème avec cette façon de faire est que le modèle aura l'impression que plus les chiffres sont proches, plus les catégories se ressemblent, donc on va préférer la transformation suivant (2.2)
#
#
# 2.2 ) sur des colonnes différentes , queqlue chose de comme ça :
#
# ![image.png](data:image/png;base64,...)
#
# (encodage à chaud conseillé) !!!

# %% [markdown]
# **3) supprimez les colonnes qui ne servent à rien comme la colonne Cabine et les 2 lignes n'ayant pas d'Embarked**

# %% [markdown]
# **4) Pour les âges manquants, remplacer les par la moyenne d'age !!!** (cela va biaiser vos données !!!)

# %% [markdown]
# A la fin de cette étape vous aurez un datarame qui ressemble un peu à ça :
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # STEP 2 : DECOUPAGE DES DONNÉES EN TRAIN ET TEST

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
# utilsiez la méthode de découpage des données de scikit-learn
from sklearn.model_selection import train_test_split

# %%
X = #TODO :::

# %%
y = #TODO :::

# %%
# ici on dit que l'on aura 33% des données qui seront des données de test
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # STEP 3 : ENTRAINER UN MODELE DE REGRESSION LOGISTIQUE AVEC LES DATA TRAIN

# %% [markdown]
# Maitnenant que vous avez vos données d'apprentissage et de test, vous pouvez entrainer un modèle de regression logistique (qui est un modèle de classification).

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
from sklearn.linear_model import LogisticRegression

# %%
# inspirez-vous du LAB 1 pour l'instanciation : récupération de l'algo d'IA
model = #TODO:::

# %%
# inspirez-vous du LAB 1 pour la suite ...

# %% [markdown]
# # STEP 4 : TESTER LE MODELE DE ML AVEC LES DATA TEST

# %%
# ici aussi inspirez-vous du lab 1

y_pred = model.predict(#TODO:::)

# %% [markdown]
# # STEP 5 : EVALUEZ ET ANALYSEZ LES PERFOMANCES DU MODELE A L'AIDE DE LA MATRICE DE CONFUSION (laquelle utilise à sont tour les y_pred et les y_test)

# %% [markdown]
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.ConfusionMatrixDisplay.html#sklearn.metrics.ConfusionMatrixDisplay

# %%
confusion_matrix(y_test, y_pred, labels=model.classes_)

# %%
# Faites une analyse quantitative à l'aide de la matrice de confusion
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=clf.classes_)
disp.plot()
plt.show()
